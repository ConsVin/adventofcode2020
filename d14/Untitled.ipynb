# %%
import numpy as np
lines = open("input.txt", "r").readlines()

mem=np.zeros(1024*64)
for l in lines:
    t = l.split('=');
    print(l.strip())
    if t[0][:3]=="mem":
        addr = int(t[0][4:-2])
        data = int(t[1])
        masked = (data | or_mask) & and_mask;
        mem[addr]=masked;
        print([addr,data, masked])
    elif t[0][:4]=="mask":
        mask = t[1][1:-1]
        and_mask =int(mask.replace('X','1'),2)
        or_mask = int(mask.replace('X','0'),2)
        print([and_mask, or_mask])
print(np.sum(mem)   )
# Out:
# mask = 001X11X1X010X1X1010XX10X100101011000
# [17095317848, 12118673752]
# mem[43398] = 563312
# [43398, 563312, 12118710616]
# mem[51673] = 263978
# [51673, 263978, 12118673752]
# mem[18028] = 544304215
# [18028, 544304215, 12657707352]
# mask = X0100001101XX11100010XX110XX11111000
# [43418483704, 9033554168]
# mem[24151] = 2013
# [24151, 2013, 9033554936]
# mem[15368] = 19793
# [15368, 19793, 9033570808]
# mem[45005] = 478
# [45005, 478, 9033554424]
# mem[1842] = 190808161
# [1842, 190808161, 9050331384]
# mem[36033] = 987
# [36033, 987, 9033554936]
# mem[26874] = 102
# [26874, 102, 9033554168]
# mask = 00X0000110110X000110010101XX0X010001
# [9047529297, 453399569]
# mem[9507] = 7
# [9507, 7, 453399569]
# mem[50019] = 16475608
# [50019, 16475608, 457594193]
# mem[4334] = 129799
# [4334, 129799, 453400337]
# mem[37373] = 182640
# [37373, 182640, 453399889]
# mem[28170] = 534617265
# [28170, 534617265, 457593873]
# mem[6432] = 354252
# [6432, 354252, 453400401]
# mem[36752] = 834628
# ...

# %%
and_mask = 15;
a = 1024;
print( a | and_mask)
# Out:
# 1039
