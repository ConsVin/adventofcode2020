# %% [markdown]
# ```
# byr (Birth Year) - four digits; at least 1920 and at most 2002.
# iyr (Issue Year) - four digits; at least 2010 and at most 2020.
# eyr (Expiration Year) - four digits; at least 2020 and at most 2030.
# hgt (Height) - a number followed by either cm or in:
# If cm, the number must be at least 150 and at most 193.
# If in, the number must be at least 59 and at most 76.
# hcl (Hair Color) - a # followed by exactly six characters 0-9 or a-f.
# ecl (Eye Color) - exactly one of: amb blu brn gry grn hzl oth.
# pid (Passport ID) - a nine-digit number, including leading zeroes.
# cid (Country ID) - ignored, missing or not.
# ```

# %%
                           
def check_dict(d):
    if not( int(d['byr']) in range(1920,2020+1)):
        return False
    if not( int(d['iyr']) in range(2010,2020+1)):
        return False
    if not( int(d['eyr']) in range(2020,2030+1)):
        return False

    height_int = int(''.join([i for i in d['hgt'] if     i.isdigit()]))
    height_pref = ''.join([i for i in d['hgt'] if not i.isdigit()])
    if (height_pref=='in'):
        if not(height_int in range(59, 76+1)):
            return False
    elif (height_pref=='cm'):
        if not(height_int in range(150, 193+1)):
            return False
    else:
        return False;
    
    if not(d['ecl'] in ['amb','blu','brn','gry','grn','hzl','oth']):
        return False
    
    if not(bool(re.match("^\\d{9}$",d["pid"]))):
        return False
    
    hclr = d["hcl"]
    if not(hclr[0]=="#"):
        return False
    if not ( bool(re.match(r"^[0-9A-F]+$",hclr[1:])))
    
    
    
    return True

demo= { 'hcl': '#6b5442', 'eyr': '2028', 'iyr': '2020', 'ecl': 'oth', 'hgt': '59in', 'pid': '432183209', 'byr': '1984'}
check_dict(demo)
# Out:
# True

# %%
import re
# Out:
# True

# %%
import re
import numpy as np
file1 = open('passport.txt', 'r') 
Lines = file1.readlines() 
  
count = 0
m_valid=0;
pass_cnt=0;

fields_mand = ["byr", "iyr", "eyr", "hgt", "hcl", "ecl", "pid"]
fields_opt  = ["cid"]
buf=''
valid_cnt=0
valid_parsed=0

    
for line in Lines: 
    if line=="\n":
        fields = buf.replace("\n"," ").split(' ')[:-1]
        field_names = [f.split(":")[0] for f in fields]
        d={}
        for f in fields:
            fname,val = f.split(":")
            d[fname]=val;
                        
        check_vec =  [ (item in field_names) for item in fields_mand]
        check = all(check_vec)
        if check:
            valid_cnt+=1;
        if (check_dict):
            valid_parsed+=1;
        print(f"{buf} \n {check_vec} \n {check} \n {field_names}\n {d} {valid_parsed}\n")
        buf=''
        pass_cnt+=1;
        print(pass_cnt)
    else:
        buf+=line;
#     print(line)
print([pass_cnt,valid_cnt])
# Out:
# byr:2010 pid:#1bb4d8 eyr:2021 hgt:186cm iyr:2020 ecl:grt
#
#  [True, True, True, True, False, True, True]
#  False
#  ['byr', 'pid', 'eyr', 'hgt', 'iyr', 'ecl']
#  {'byr': '2010', 'pid': '#1bb4d8', 'eyr': '2021', 'hgt': '186cm', 'iyr': '2020', 'ecl': 'grt'} 1
#
# 1
# pid:937877382 eyr:2029
# ecl:amb hgt:187cm iyr:2019
# byr:1933 hcl:#888785
#
#  [True, True, True, True, True, True, True]
#  True
#  ['pid', 'eyr', 'ecl', 'hgt', 'iyr', 'byr', 'hcl']
#  {'pid': '937877382', 'eyr': '2029', 'ecl': 'amb', 'hgt': '187cm', 'iyr': '2019', 'byr': '1933', 'hcl': '#888785'} 2
#
# 2
# ecl:hzl
# eyr:2020
# hcl:#18171d
# iyr:2019 hgt:183cm
# byr:1935
#
#  [True, True, True, True, True, True, False]
#  False
#  ['ecl', 'eyr', 'hcl', 'iyr', 'hgt', 'byr']
#  {'ecl': 'hzl', 'eyr': '2020', 'hcl': '#18171d', 'iyr': '2019', 'hgt': '183cm', 'byr': '1935'} 3
#
# 3
# hcl:#7d3b0c hgt:183cm cid:135
# byr:1992 eyr:2024 iyr:2013 pid:138000309
# ecl:oth
#
#  [True, True, True, True, True, True, True]
#  True
# ...
